# %%
import time
start=time.time()
for i in range(1,10,1):
    print(i)
print("Time taken: ", time.time()-start)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# Time taken:  0.0011057853698730469

# %%
import time
start=time.time()
i = 1
while i < 10:
    print(i)
    i += 1
print("Time taken: ", time.time()-start)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# Time taken:  0.0010116100311279297

# %% [markdown]
# ##  problems with the above code  are:
# 1. different time for different algorithm
# 2. time varies if implemenetation changes
# 3. different machine will give different time
# 4. does not work for extremely small output
# 5. time varies for different inputd but cant establish a relationship

# %%
## dynamicv array
import ctypes
## ctype is a library that provides C compatible data types and allows calling functions

# %%
class meralist:
    def __init__(self):
        self.size=1 ## no of items can be stored
        self.n=0 ## no of items actually stored
        ## create a c type arry of size=self.size
        self.A=self.make_array(self.size)

    def make_array(self, capacity):
        ## this code creates a c type array(static,referncial) with size capacity
        return (capacity*ctypes.py_object)()
    
    def __len__(self):
        return self.n
    
    def __append__(self,item):
        if self.n==self.size:
            self.__resize(self.size*2)

        self.A[self.n]=item
        self.n+=1

    def __resize(self,capacity):
       ## create a array of new capacity
        B=self.make_array(capacity)
        self.size=capacity
        ## copy the old elements to new array
        for i in range(self.n):
            B[i]=self.A[i]
        ## reassign A
        self.A=B
        
    def __make_array(self, capacity):
        ## this code creates a c type array(static,referncial) with size capacity
        return (capacity*ctypes.py_object)()

# %%
## create a list
L=meralist()

# %%
print(L)

# %%
len(L)
# Out:
# 0
